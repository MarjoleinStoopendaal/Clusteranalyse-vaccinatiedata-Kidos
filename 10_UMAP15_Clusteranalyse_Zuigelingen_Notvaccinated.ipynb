# %% [markdown]
# ### 1. Import modules

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.gridspec import GridSpec
from matplotlib.colors import ListedColormap
from sklearn.metrics import silhouette_score
import hdbscan
import geopandas as gpd
import contextily as ctx
from geopy.geocoders import Nominatim
from tqdm.notebook import tqdm
from geopy.extra.rate_limiter import RateLimiter

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
import shap
from sklearn import tree

import sys
import os
sys.path.append(os.path.abspath('..'))
from datetime import datetime
from functions.shap_forceplots import clust_shap_force

# %% [markdown]
# ### 2. Import zuigelingen

# %%
# Choose embedded space to work with
embedded_space = 'intersection'

# Load datasets
if embedded_space == 'intersection':
    X_zuigelingen_UMAP15 = np.load('../4_Data\Arrays\X_zuigelingen_notvaccinated_UMAP15_intersection1.npy')
elif embedded_space == 'union':
    X_zuigelingen_UMAP15 = np.load('../4_Data\Arrays\X_zuigelingen_notvaccinated_UMAP15_union1.npy')

y_zuigelingen = np.load('../4_Data/Arrays/y_zuigelingen.npy')

# Original variables
zuigelingen = pd.read_pickle('../4_Data/Pickles/zuigelingen.pkl')
X_zuigelingen_notvaccinated = pd.read_pickle('../4_Data/Pickles/X_zuigelingen_notvaccinated.pkl')
X_zuigelingen_vaccinated = pd.read_pickle('../4_Data/Pickles/X_zuigelingen_vaccinated.pkl')

# Split subset of X_zuigelingen for rows which were 'Vaccinated' in y_zuigelingen
zuigelingen = zuigelingen[y_zuigelingen == 0]

# %%
# Loop over every column name in a df
def column_cleaner(df):
    for column in df.columns:
        ## Remove categories
        # Get position of last capital letter by iterating backwards
        pos = 0
        for i in range(len(column)-1, 0, -1):
            if column[i].isupper() and (column[i-1].islower() or column[i-1] == '_'):
                pos = i
                break
        # If there is a capital letter
        if pos != 0 and column[-1] != '_':
            # Remove everything after the before capital letter
            df.rename(columns={column: column[pos:]}, inplace=True)
        elif pos != 0 and column[-1] == '_':
            df.rename(columns={column: column[pos:] + '%'}, inplace=True)
    return df

# Manually set some other column names
def column_editor(df):
    df.rename(columns={'Inkomen_van_huishoudens40_huishoudens_met_laagste_inkomen_%': 'Huishoudens_laagste_landelijke_40%_huishoudensinkomens_%'}, inplace=True)
    df.rename(columns={'Inkomen_van_huishoudens20_huishoudens_met_hoogste_inkomen_%': 'Huishoudens_hoogste_landelijke_20%_huishoudensinkomens_%'}, inplace=True)
    df.rename(columns={'Huishoudens_tot_110_van_sociaal_minimum_%': 'Huishoudens_tot_110%_van_sociaal_minimum_%'}, inplace=True)
    df.rename(columns={'Huishoudens_tot_120_van_sociaal_minimum_%': 'Huishoudens_tot_120%_van_sociaal_minimum_%'}, inplace=True)
    df.rename(columns={'Personenautos_per_huishouden_per_huishouden': 'Personenautos_per_huishouden'}, inplace=True)
    df.rename(columns={'stedelijkheid_1.0': 'zeer_sterk_stedelijk'}, inplace=True)
    df.rename(columns={'stedelijkheid_2.0': 'sterk_stedelijk'}, inplace=True)
    df.rename(columns={'stedelijkheid_3.0': 'matig_stedelijk'}, inplace=True)
    df.rename(columns={'stedelijkheid_4.0': 'weinig_stedelijk'}, inplace=True)
    df.rename(columns={'stedelijkheid_5.0': 'niet_stedelijk'}, inplace=True)
    return df

# %%
# Clean notvaccinated
column_cleaner(X_zuigelingen_notvaccinated)
column_editor(X_zuigelingen_notvaccinated)

# Clean vaccinated
column_cleaner(X_zuigelingen_vaccinated)
column_editor(X_zuigelingen_vaccinated)
# Out:
#       gemiddelde_woz_waarde_woning  Nettoarbeidsparticipatie_%  \
# 0                            518.0                        66.0
# 1                            306.0                        46.0
# 3                            307.0                        66.0
# 4                            328.0                        73.0
# 5                            372.0                        78.0
# ...                            ...                         ...
# 5379                         336.0                        76.0
# 5380                         264.0                        67.0
# 5381                         336.0                        72.0
# 5382                         280.0                        64.0
# 5383                         340.0                        72.0
#
#       Huishoudens_laagste_landelijke_40%_huishoudensinkomens_%  \
# 0                                                25.300
# 1                                                68.800
# 3                                                30.200
# 4                                                26.800
# 5                                                14.300
# ...                                                 ...
# 5379                                             20.800
# 5380                                             25.400
# 5381                                             38.100
# 5382                                             48.500
# 5383                                             22.846
#
#       Huishoudens_hoogste_landelijke_20%_huishoudensinkomens_%  \
# 0                                                 37.30
# 1                                                  7.60
# 3                                                 13.80
# 4                                                 32.40
# 5                                                 38.10
# ...                                                 ...
# 5379                                              36.60
# 5380                                              18.90
# 5381                                              23.20
# 5382                                              10.40
# 5383                                              43.73
#
#       Huishoudens_met_een_laag_inkomen_%  \
# 0                                   2.60
# 1                                   8.20
# 3                                   1.80
# 4                                   2.60
# 5                                   3.00
# ...                                  ...
# 5379                                1.70
# 5380                                2.40
# 5381                                2.30
# 5382                                5.50
# 5383                                4.51
#
#       Huish_onder_of_rond_sociaal_minimum_%  \
# 0                                     3.600
# 1                                    14.800
# 3                                     2.400
# 4                                     3.700
# 5                                     2.300
# ...                                     ...
# 5379                                  0.700
# 5380                                  3.400
# 5381                                  2.700
# 5382                                  7.100
# 5383                                  4.248
#
#       Huishoudens_tot_110%_van_sociaal_minimum_%  \
# 0                                          5.700
# 1                                         22.100
# 3                                          2.900
# 4                                          6.200
# 5                                          3.300
# ...                                          ...
# 5379                                       1.200
# 5380                                       4.700
# 5381                                       4.900
# 5382                                      11.700
# 5383                                       7.322
#
#       Huishoudens_tot_120%_van_sociaal_minimum_%  \
# 0                                           8.10
# 1                                          31.90
# 3                                           4.20
# 4                                           8.30
# 5                                           3.80
# ...                                          ...
# 5379                                        2.20
# 5380                                        6.50
# 5381                                        8.00
# 5382                                       16.40
# 5383                                        9.58
#
#       Mediaan_vermogen_van_particuliere_huish_x_1_000_euro  \
# 0                                               476.400
# 1                                                 7.700
# 3                                               193.600
# 4                                               223.700
# 5                                               256.400
# ...                                                 ...
# 5379                                            365.800
# 5380                                            163.800
# 5381                                            287.200
# 5382                                             37.100
# 5383                                            650.253
#
#       Percentage_jongeren_met_jeugdzorg_%  ...  Migrant  Nederlands  \
# 0                                    9.20  ...    False        True
# 1                                   10.60  ...    False        True
# 3                                   12.10  ...    False        True
# 4                                   11.10  ...    False        True
# 5                                   11.20  ...    False        True
# ...                                   ...  ...      ...         ...
# 5379                                 6.50  ...    False        True
# 5380                                13.60  ...    False       False
# 5381                                11.30  ...    False        True
# 5382                                12.90  ...    False        True
# 5383                                 7.62  ...    False       False
#
#       CBS_indeling_nan  Toestemming_0.0  Toestemming_1.0  Toestemming_nan  \
# 0                False            False             True            False
# 1                False            False             True            False
# 3                False            False             True            False
# 4                False            False             True            False
# 5                False            False             True            False
# ...                ...              ...              ...              ...
# 5379             False            False             True            False
# 5380              True            False             True            False
# 5381             False            False             True            False
# 5382             False            False             True            False
# 5383              True            False            False             True
#
#       Tweeling  Geslacht=mannelijk  Gevaccineerd_ouder1  Gevaccineerd_ouder2
# 0        False                True                 True                 True
# 1        False               False                False                False
# 3        False               False                 True                 True
# 4        False                True                 True                 True
# 5        False                True                 True                 True
# ...        ...                 ...                  ...                  ...
# 5379     False               False                 True                 True
# 5380     False                True                 True                 True
# 5381     False               False                 True                 True
# 5382     False                True                False                False
# 5383     False               False                 True                 True
#
# [4899 rows x 82 columns]

# %% [markdown]
# ### 3. Clustering

# %%
# Save hyperparameters
min_cluster_size = 25
min_samples = 10

# Fit HDBSCAN
hdb = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size, min_samples=min_samples)
hdb.fit(X_zuigelingen_UMAP15)
print(hdb.labels_)
# Out:
# [1 2 0 1 2 0 2 1 1 1 0 2 2 2 1 0 0 1 1 0 2 0 1 1 2 0 2 1 2 1 2 0 1 0 1 2 2
#  2 2 2 2 2 2 1 2 1 1 1 2 2 2 2 1 1 1 2 1 2 1 0 2 0 1 1 0 0 2 2 0 1 0 1 1 1
#  0 1 2 1 1 0 0 1 1 2 1 1 1 2 2 2 2 2 1 2 2 0 2 1 1 2 0 1 2 0 2 1 1 2 1 2 2
#  2 2 2 2 2 2 1 2 0 2 1 0 2 0 2 0 1 2 2 0 2 0 2 2 2 0 0 2 2 2 2 2 2 1 1 2 1
#  1 1 0 2 2 1 2 1 2 0 0 0 2 2 0 0 2 0 0 2 0 1 1 0 2 2 2 1 1 1 2 1 1 0 2 2 1
#  1 2 1 2 2 2 0 1 0 2 1 1 0 2 1 0 1 2 0 1 0 1 2 1 2 1 2 2 2 0 2 0 1]

# %%
# Calculate silhouette score excluding noise cluster
if -1 in hdb.labels_:
    silhouette = silhouette_score(X_zuigelingen_UMAP15[hdb.labels_ != -1], hdb.labels_[hdb.labels_ != -1])
else:
    silhouette = silhouette_score(X_zuigelingen_UMAP15, hdb.labels_)

print(f'The silhouette score is: {silhouette}')
# Out:
# The silhouette score is: 0.613301694393158

# %%
# If -1 is in the labels, begin with second color in palette
if -1 in hdb.labels_:
    plt.figure(figsize=(12, 7))
    plt.title(f'HDBSCAN clustering with silhouette score {silhouette:.2f} - (min_cluster_size={min_cluster_size}, min_samples={min_samples})')
    hdb.condensed_tree_.plot(select_clusters=True, selection_palette=sns.color_palette()[1:])
else:
    plt.figure(figsize=(12, 7))
    plt.title(f'HDBSCAN clustering with silhouette score {silhouette:.2f} - (min_cluster_size={min_cluster_size}, min_samples={min_samples})')
    hdb.condensed_tree_.plot(select_clusters=True, selection_palette=sns.color_palette())

# %%
# Plot sns.color_palette() to see the colors used in the plot
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
# Get amount of unique values in an array
unique, counts = np.unique(hdb.labels_, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 49, 1: 74, 2: 95}

# %%
# Calculate the amount of clusters
if -1 in hdb.labels_:
    n_clusters = len(np.unique(hdb.labels_)) - 1 # Subtract 1 because of the noise cluster
else:
    n_clusters = len(np.unique(hdb.labels_))
print(f'The amount of clusters derived is: {n_clusters}')
# Out:
# The amount of clusters derived is: 3

# %%
# Calculate silhouette score excluding noise cluster
if -1 in hdb.labels_:
    silhouette = silhouette_score(X_zuigelingen_UMAP15[hdb.labels_ != -1], hdb.labels_[hdb.labels_ != -1])
else:
    silhouette = silhouette_score(X_zuigelingen_UMAP15, hdb.labels_)

print(f'The silhouette score is: {silhouette}')
# Out:
# The silhouette score is: 0.613301694393158

# %% [markdown]
# ### 4. Interpretation of clustering results

# %% [markdown]
# #### 4.1 Random Forest predictive capability

# %%
# Save cluster labels as y
y_clusters_zuigelingen = hdb.labels_

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_zuigelingen_notvaccinated, y_clusters_zuigelingen, test_size=0.3, random_state=42)

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %%
# Initialize the Random Forest Classifier
clf_rf = RandomForestClassifier(random_state=42)

# Train the classifier
clf_rf.fit(X_train, y_train)

# Make predictions
y_pred = clf_rf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f'Accuracy: {accuracy:.2f}')

# Print classification report
print('Classification Report:')
print(classification_report(y_test, y_pred))

# Print confusion matrix
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.00
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        30
#
#     accuracy                           1.00        66
#    macro avg       1.00      1.00      1.00        66
# weighted avg       1.00      1.00      1.00        66
#
# Confusion Matrix:
# [[15  0  0]
#  [ 0 21  0]
#  [ 0  0 30]]

# %%
# Create a SHAP explainer
explainer = shap.TreeExplainer(clf_rf)
shap_values = explainer.shap_values(X_train)

# %%
le_classes = np.unique(y_clusters_zuigelingen)

# %%
clust_shap_force(clf_rf, 23,
                 X_train, y_train,
                 explainer,
                 shap_values,
                 le_classes,
                 classes='all')
# Out:
# ***************************************************
# Ground Truth Label: 0 - 0
#
# Model Prediction:  [0] - 0 -- Correct!
# ***************************************************
#
#
# 0 Class (0)
# <div id='i2CV3W061YN07RD0KBEWV'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.2240131578947369, "outValue": 1.0000000000000002, "link": "identity", "featureNames": ["gemiddelde_woz_waarde_woning", "Nettoarbeidsparticipatie_%", "Huishoudens_laagste_landelijke_40%_huishoudensinkomens_%", "Huishoudens_hoogste_landelijke_20%_huishoudensinkomens_%", "Huishoudens_met_een_laag_inkomen_%", "Huish_onder_of_rond_sociaal_minimum_%", "Huishoudens_tot_110%_van_sociaal_minimum_%", "Huishoudens_tot_120%_van_sociaal_minimum_%", "Mediaan_vermogen_van_particuliere_huish_x_1_000_euro", "Percentage_jongeren_met_jeugdzorg_%", "Personenautos_per_huishouden", "Siblings", "aandeel_mannen", "aandeel_vrouwen", "aandeel_inwoners_0_tot_15_jaar", "aandeel_inwoners_15_tot_25_jaar", "aandeel_inwoners_25_tot_45_jaar", "aandeel_inwoners_45_tot_65_jaar", "Gehuwd_aandeel", "Gescheiden_aandeel", "Marokko_aandeel", "Aruba_aandeel", "Suriname_aandeel", "Turkije_aandeel", "Overig_nietwesters_aandeel", "Opleidingsniveau_laag_aandeel", "Opleidingsniveau_hoog_aandeel", "Bijstand_aandeel", "AO_aandeel", "WW_aandeel", "AOW_aandeel", "Jongeren_met_jeugdzorg_in_natura_aandeel", "aandeel_eenpersoonshuishoudens", "aandeel_meerpersoonshuishoudens_zonder_kind", "aandeel_eenouderhuishoudens", "aandeel_tweeouderhuishoudens", "aandeel_personen_met_uitkering_onder_aowlft", "aandeel_meergezins_woningen", "aandeel_huurwoningen_in_bezit_woningcorporaties", "aandeel_niet_bewoonde_woningen", "Leeftijd_moeder", "Leeftijd_ouder2",
"Toestemming_1.0", "Toestemming_nan", "Tweeling", "Geslacht=mannelijk", "Gevaccineerd_ouder1", "Gevaccineerd_ouder2"], "features": {"0": {"effect": -0.025570034337569127, "value": 306.0}, "1": {"effect": -2.3184673001091054e-05, "value": 46.0}, "2": {"effect": -0.0009756034819013943, "value": 68.8}, "3": {"effect": -0.003322073512419437, "value": 7.6}, "4": {"effect": -0.002913376349005959, "value": 8.2}, "5": {"effect": -0.0024344722804529734, "value": 14.8}, "6": {"effect": -0.007411689007773919, "value": 22.1}, "7": {"effect": -0.0046290901524893725, "value": 31.9}, "8": {"effect": -0.011561444983508903, "value": 7.7}, "9": {"effect": -6.438810845207498e-05, "value": 10.6}, "10": {"effect": -0.0020060104644782535, "value": 0.7}, "11": {"effect": -0.00023526749286005712, "value": 1.0}, "12": {"effect": -0.008731112752417586, "value": 0.49521829521829525}, "13": {"effect": -0.014317998855134757, "value": 0.5051975051975052}, "14": {"effect": 0.004509533079021533, "value": 0.15592515592515593}, "15": {"effect": 0.002118124823235695, "value": 0.11891891891891893}, "16": {"effect": 0.006220670323414823, "value": 0.2087 ...
#     document.getElementById('iI1ZTMVSZNC1LCR2KPUDP')
#   );
# </script>

# %%
# Split the array into a list of arrays, one for each class
multi_shap_vals = [shap_values[:, :, i] for i in range(shap_values.shape[2])]

# Plot the SHAP values with feature names
shap.summary_plot(multi_shap_vals, X_train.values, plot_type='bar', class_names=le_classes, feature_names=X_train.columns, plot_size=(15, 10))

# %%
# Print summary plot per cluster
for cluster in range(len(le_classes)):
    shap.summary_plot(shap_values[:, :, cluster], X_train, feature_names=X_train.columns, plot_size=(15, 10))

# %% [markdown]
# #### 4.2 Neighbourhood plots

# %%
# Take only relevant columns
zuigelingen_buurt = zuigelingen[['BuurtCode']]

# Add the cluster labels to the original dataset
zuigelingen_buurt['Cluster_label'] = hdb.labels_

# Get all unique Cluster_label values
all_cluster_labels = zuigelingen_buurt['Cluster_label'].unique()

# Calculate the percentages of 'Cluster_label' per unique CBS_Buurtcode_BRP
buurt_percentages = zuigelingen_buurt.groupby('BuurtCode')['Cluster_label'].value_counts(normalize=True).unstack().fillna(0)

# Reindex to ensure all unique Cluster_label values are included as columns
buurt_percentages = buurt_percentages.reindex(columns=all_cluster_labels, fill_value=0)

# Reset index
buurt_percentages = buurt_percentages.reset_index()

# Reading GeoPackage file
cbs_df = gpd.read_file('../4_Data/Polygons/buurten_2023_v1.shp')

# Replace every -99997 with NaN
cbs_df = cbs_df.replace(-99997, np.nan)

# From every row in 'BU_CODE' remove the first two characters
cbs_df['BU_CODE'] = cbs_df['BU_CODE'].astype(str).str[2:]

# Define list of relevant municipalities
municipalities = ['Alphen-Chaam',
                  'Altena',
                  'Baarle-Nassau',
                  'Breda',
                  'Drimmelen',
                  'Etten-Leur',
                  'Geertruidenberg',
                  'Halderberge',
                  'Oosterhout',
                  'Zundert']

# Filter the df_pc4 to only include the relevant municipalities
cbs_df = cbs_df[cbs_df['GM_NAAM'].isin(municipalities)]

# Merge polygons with percentages for all clusters
gdf = cbs_df.merge(buurt_percentages[['BuurtCode'] + list(range(n_clusters))], left_on='BU_CODE', right_on='BuurtCode', how='left')

# %% [markdown]
# #### 4.3 Comparison of central tendency

# %%
# Take only float64 and int64 columns
X_zuigelingen_continuous = X_zuigelingen_notvaccinated.select_dtypes(include=['float64', 'int64'])

# Add 'Zuigelingen_status' to the DataFrame
X_zuigelingen_continuous['Cluster'] = y_clusters_zuigelingen

# Group X_zuigelingen by Zuigelingen_status and calculate mean
grouped_continuous = X_zuigelingen_continuous.groupby('Cluster').mean()

# Transpose the DataFrame
grouped_continuous = grouped_continuous.T

# Add the calculated measures of central tendency as new columns to grouped_continuous
grouped_continuous['Gemiddelde (niet gevaccineerden)'] = X_zuigelingen_continuous.mean()
grouped_continuous['Mediaan (niet gevaccineerden)'] = X_zuigelingen_continuous.median()
grouped_continuous['SD (niet gevaccineerden)'] = X_zuigelingen_continuous.std()

# Add the calculated box plot statistics as new columns to grouped_continuous
grouped_continuous['Q1 (niet gevaccineerden)'] = X_zuigelingen_continuous.quantile(0.25)
grouped_continuous['Q3 (niet gevaccineerden)'] = X_zuigelingen_continuous.quantile(0.75)
grouped_continuous['IQR (niet gevaccineerden)'] = grouped_continuous['Q3 (niet gevaccineerden)'] - grouped_continuous['Q1 (niet gevaccineerden)']
grouped_continuous['Ondergrens uitschieters (niet gevaccineerden)'] = grouped_continuous['Q1 (niet gevaccineerden)'] - 1.5 * grouped_continuous['IQR (niet gevaccineerden)']
grouped_continuous['Bovengrens uitschieters (niet gevaccineerden)'] = grouped_continuous['Q3 (niet gevaccineerden)'] + 1.5 * grouped_continuous['IQR (niet gevaccineerden)']

# Add X_zuigelingen_vaccinated means and medians to grouped_continuous
grouped_continuous['Gemiddelde (gevaccineerden)'] = X_zuigelingen_vaccinated.select_dtypes(include=['float64', 'int64']).mean()
grouped_continuous['Mediaan (gevaccineerden)'] = X_zuigelingen_vaccinated.select_dtypes(include=['float64', 'int64']).median()
grouped_continuous['SD (gevaccineerden)'] = X_zuigelingen_vaccinated.select_dtypes(include=['float64', 'int64']).std()
grouped_continuous
# Out:
# Cluster                                                      0           1  \
# gemiddelde_woz_waarde_woning                        288.918367  298.513514
# Nettoarbeidsparticipatie_%                           60.367347   69.551622
# Huishoudens_laagste_landelijke_40%_huishoudensi...   42.993878   34.571095
# Huishoudens_hoogste_landelijke_20%_huishoudensi...   14.326531   22.246203
# Huishoudens_met_een_laag_inkomen_%                    5.206122    3.286351
# Huish_onder_of_rond_sociaal_minimum_%                 7.775510    3.794041
# Huishoudens_tot_110%_van_sociaal_minimum_%           11.842857    6.056176
# Huishoudens_tot_120%_van_sociaal_minimum_%           15.479592    8.685149
# Mediaan_vermogen_van_particuliere_huish_x_1_000...   87.773469  170.639500
# Percentage_jongeren_met_jeugdzorg_%                  12.002837    7.838081
# Personenautos_per_huishouden                          1.088735    1.216243
# Siblings                                              1.428571    2.307568
# aandeel_mannen                                        0.493046    0.498601
# aandeel_vrouwen                                       0.507075    0.501399
# aandeel_inwoners_0_tot_15_jaar                        0.154540    0.186738
# aandeel_meerpersoonshuishoudens_zonder_kind           0.330640
# aandeel_eenouderhuishoudens                           0.056142
# aandeel_tweeouderhuishoudens                          0.336521
# aandeel_personen_met_uitkering_onder_aowlft           0.047311
# aandeel_meergezins_woningen                           0.128236
# aandeel_huurwoningen_in_bezit_woningcorporaties       0.194802
# aandeel_niet_bewoonde_woningen                        0.040713
# Leeftijd_moeder                                      30.781096
# Leeftijd_ouder2                                      33.738289
#
# Cluster                                             Gemiddelde (niet gevaccineerden)  \
# gemiddelde_woz_waarde_woning                                              316.220183
# Nettoarbeidsparticipatie_%                                                 67.263853
# Huishoudens_laagste_landelijke_40%_huishoudensi...                         34.271775
# Huishoudens_hoogste_landelijke_20%_huishoudensi...                         22.716188
# Huishoudens_met_een_laag_inkomen_%                                          3.346761
# Huish_onder_of_rond_sociaal_minimum_%                                       4.386459
# Huishoudens_tot_110%_van_sociaal_minimum_%                                  6.953399
# Huishoudens_tot_120%_van_sociaal_minimum_%                                  9.530913
# Mediaan_vermogen_van_particuliere_huish_x_1_000...                        195.472211
# Percentage_jongeren_met_jeugdzorg_%                                         9.216927
# Personenautos_per_huishouden                                                1.248853
# Siblings                                                                    1.907294
# aandeel_mannen                                                              0.499929
# aandeel_vrouwen                                                             0.500014
# aandeel_inwoners_0_tot_15_jaar                                              0.171454
# aandeel_inwoners_15_tot_25_jaar                                             0.121362
# aandeel_inwoners_25_tot_45_jaar                                             0.226355
# aandeel_inwoners_45_tot_65_jaar                                             0.274787
# Gehuwd_aandeel                                                              0.443823
# Gescheiden_aandeel                                                          0.063932
# Marokko_aandeel                                                             0.015463
# Aruba_aandeel                                                               0.003867
# Suriname_aandeel                                                            0.003341
# Turkije_aandeel                                                             0.010864
# Overig_nietwesters_aandeel                                                  0.034884
# Opleidingsniveau_laag_aandeel                                               0.248545
# Opleidingsniveau_hoog_aandeel                                               0.153268
# Bijstand_aandeel                                                            0.015706
# AO_aandeel                                                                  0.035615
# WW_aandeel                                                                  0.005271
# AOW_aandeel                                                                 0.189823
# Jongeren_met_jeugdzorg_in_natura_aandeel                                    0.024931
# aandeel_eenpersoonshuishoudens                                              0.292352
# aandeel_meerpersoonshuishoudens_zonder_kind                                 0.322000
# aandeel_eenouderhuishoudens                                                 0.061803
# aandeel_tweeouderhuishoudens                                                0.324114
# aandeel_personen_met_uitkering_onder_aowlft                                 0.054049
# aandeel_meergezins_woningen                                                 0.160143
# aandeel_huurwoningen_in_bezit_woningcorporaties                             0.264494
# aandeel_niet_bewoonde_woningen                                              0.035280
# Leeftijd_moeder                                                            29.922202
# Leeftijd_ouder2                                                            32.710233
#
# Cluster                                             Mediaan (niet gevaccineerden)  \
# gemiddelde_woz_waarde_woning                                           306.000000
# Nettoarbeidsparticipatie_%                                              67.000000
# Huishoudens_laagste_landelijke_40%_huishoudensi...                      34.500000
# Huishoudens_hoogste_landelijke_20%_huishoudensi...                      21.150000
# Huishoudens_met_een_laag_inkomen_%                                       3.300000
# Huish_onder_of_rond_sociaal_minimum_%                                    3.700000
# Huishoudens_tot_110%_van_sociaal_minimum_%                               6.100000
# Huishoudens_tot_120%_van_sociaal_minimum_%                               8.500000
# Mediaan_vermogen_van_particuliere_huish_x_1_000...
niet gevaccineerden)  \
# gemiddelde_woz_waarde_woning                                      301.000000
# Nettoarbeidsparticipatie_%                                         65.000000
# Huishoudens_laagste_landelijke_40%_huishoudensi...                 29.400000
# Huishoudens_hoogste_landelijke_20%_huishoudensi...                 17.225000
# Huishoudens_met_een_laag_inkomen_%                                  2.025000
# Huish_onder_of_rond_sociaal_minimum_%                               2.925000
# Huishoudens_tot_110%_van_sociaal_minimum_%                          5.000000
# Huishoudens_tot_120%_van_sociaal_minimum_%                          7.000000
# Mediaan_vermogen_van_particuliere_huish_x_1_000...                140.300000
# Percentage_jongeren_met_jeugdzorg_%                                 7.025000
# Personenautos_per_huishouden                                        1.100000
# Siblings                                                            1.000000
# aandeel_mannen                                                      0.495245
# aandeel_vrouwen                                                     0.496681
# aandeel_inwoners_0_tot_15_jaar                                      0.154495
# aandeel_inwoners_15_tot_25_jaar                                     0.108032
# aandeel_inwoners_25_tot_45_jaar                                     0.220240
# aandeel_inwoners_45_tot_65_jaar                                     0.255432
# Gehuwd_aandeel                                                      0.424864
# Gescheiden_aandeel                                                  0.048387
# Marokko_aandeel                                                     0.000000
# Aruba_aandeel                                                       0.000000
# Suriname_aandeel                                                    0.000000
# Turkije_aandeel                                                     0.000000
# Overig_nietwesters_aandeel                                          0.019406
# Opleidingsniveau_laag_aandeel                                       0.212121
# Opleidingsniveau_hoog_aandeel                                       0.106667
# Bijstand_aandeel                                                    0.007547
# AO_aandeel                                                          0.030303
# WW_aandeel                                                          0.000000
# AOW_aandeel                                                         0.156098
# Jongeren_met_jeugdzorg_in_natura_aandeel                            0.020896
# aandeel_eenpersoonshuishoudens                                      0.274900
# aandeel_meerpersoonshuishoudens_zonder_kind                         0.307692
# aandeel_eenouderhuishoudens                                         0.053613
# aandeel_tweeouderhuishoudens                                        0.288069
# aandeel_personen_met_uitkering_onder_aowlft                         0.044789
# aandeel_meergezins_woningen                                         0.114990
# aandeel_huurwoningen_in_bezit_woningcorporaties                     0.200000
# aandeel_niet_bewoonde_woningen                                      0.028777
# Leeftijd_moeder                                                    26.375000
# Leeftijd_ouder2                                                    28.354167
#
# Cluster                                             Q3 (niet gevaccineerden)  \
# gemiddelde_woz_waarde_woning                                      335.000000
# Nettoarbeidsparticipatie_%                                         71.000000
# Huishoudens_laagste_landelijke_40%_huishoudensi...                 36.500000
# Huishoudens_hoogste_landelijke_20%_huishoudensi...                 25.700000
# Huishoudens_met_een_laag_inkomen_%                                  4.300000
# Huish_onder_of_rond_sociaal_minimum_%                               5.000000
# Huishoudens_tot_110%_van_sociaal_minimum_%                          8.000000
# Huishoudens_tot_120%_van_sociaal_minimum_%                         10.900000
# Mediaan_vermogen_van_particuliere_huish_x_1_000...                237.100000
# Percentage_jongeren_met_jeugdzorg_%                                11.200000
# Personenautos_per_huishouden                                        1.400000
# Siblings                                                            2.570000
# aandeel_mannen                                                      0.502520
# aandeel_vrouwen                                                     0.505066
# aandeel_inwoners_0_tot_15_jaar                                      0.191574
# aandeel_inwoners_15_tot_25_jaar                                     0.136142
# aandeel_inwoners_25_tot_45_jaar                                     0.231808
# aandeel_inwoners_45_tot_65_jaar                                     0.287734
# Gehuwd_aandeel                                                      0.466346
# Gescheiden_aandeel                                                  0.075501
# Marokko_aandeel                                                     0.009504
# Aruba_aandeel                                                       0.004737
# Suriname_aandeel                                                    0.004587
# Turkije_aandeel                                                     0.012526
# Overig_nietwesters_aandeel                                          0.037946
# Opleidingsniveau_laag_aandeel                                       0.295533
# Opleidingsniveau_hoog_aandeel                                       0.169355
# Bijstand_aandeel                                                    0.022146
# AO_aandeel                                                          0.037578
# WW_aandeel                                                          0.008060
# AOW_aandeel                                                         0.229114
# Jongeren_met_jeugdzorg_in_natura_aandeel                            0.028463
# aandeel_eenpersoonshuishoudens                                      0.303442
# aandeel_meerpersoonshuishoudens_zonder_kind                         0.340935
# aandeel_eenouderhuishoudens                                         0.071354
# aandeel_tweeouderhuishoudens                                        0.357809
# aandeel_personen_met_uitkering_onder_aowlft                         0.063282
# aandeel_meergezins_woningen                                         0.188119
# aandeel_huurwoningen_in_bezit_woningcorporaties                     0.297495
# aandeel_niet_bewoonde_woningen                                      0.040000
# Leeftijd_moeder                                                    32.729167
# Leeftijd_ouder2                                                    36.000000
#
# Cluster                                             IQR (niet gevaccineerden)  \
# gemiddelde_woz_waarde_woning                                        34.000000
# Nettoarbeidsparticipatie_%                                           6.000000
# Huishoudens_laagste_landelijke_40%_huishoudensi...                   7.100000
# Huishoudens_hoogste_landelijke_20%_huishoudensi...                   8.475000
# Huishoudens_met_een_laag_inkomen_%                                   2.275000
# Huish_onder_of_rond_sociaal_minimum_%                                2.075000
# Huishoudens_tot_110%_van_sociaal_minimum_%                           3.000000
# Huishoudens_tot_120%_van_sociaal_minimum_%                           3.900000
# Mediaan_vermogen_van_particuliere_huish_x_1_000...                  96.800000
# Percentage_jongeren_met_jeugdzorg_%                                  4.175000
# Personenautos_per_huishouden                                         0.300000
# Siblings                                                             1.570000
# aandeel_mannen                                                       0.007275
# aandeel_vrouwen                                                      0.008386
# aandeel_inwoners_0_tot_15_jaar                                       0.037080
# aandeel_inwoners_15_tot_25_jaar                                      0.028110
# aandeel_inwoners_25_tot_45_jaar                                      0.011568
# aandeel_inwoners_45_tot_65_jaar                                      0.032302
# Gehuwd_aandeel                                                       0.041482
# Gescheiden_aandeel                                                   0.027114
# Marokko_aandeel                                                      0.009504
# Aruba_aandeel                                                        0.004737
# Suriname_aandeel                                                     0.004587
# Turkije_aandeel                                                      0.012526
# Overig_nietwesters_aandeel                                           0.018540
# Opleidingsniveau_laag_aandeel                                        0.083411
# Opleidingsniveau_hoog_aandeel                                        0.062688
# Bijstand_aandeel                                                     0.014599
# AO_aandeel                                                           0.007275
# WW_aandeel                                                           0.008060
# AOW_aandeel                                                          0.073017
# Jongeren_met_jeugdzorg_in_natura_aandeel                             0.007567
# aandeel_eenpersoonshuishoudens                                       0.028542
# aandeel_meerpersoonshuishoudens_zonder_kind                          0.033243
# aandeel_eenouderhuishoudens                                          0.017741
# aandeel_tweeouderhuishoudens                                         0.069740
# aandeel_personen_met_uitkering_onder_aowlft                          0.018493
# aandeel_meergezins_woningen                                          0.073129
# aandeel_huurwoningen_in_bezit_woningcorporaties                      0.097495
# aandeel_niet_bewoonde_woningen                                       0.011223
# Leeftijd_moeder                                                      6.354167
# Leeftijd_ouder2                                                      7.645833
#
# Cluster                                             Ondergrens uitschieters (niet gevaccineerden)  \
# gemiddelde_woz_waarde_woning                                                           250.000000
# Nettoarbeidsparticipatie_%                                                              56.000000
# Huishoudens_laagste_landelijke_40%_huishoudensi...                                      18.750000
# Huishoudens_hoogste_landelijke_20%_huishoudensi...                                       4.512500
# Huishoudens_met_een_laag_inkomen_%                                                      -1.387500
# Huish_onder_of_rond_sociaal_minimum_%                                                   -0.187500
# Huishoudens_tot_110%_van_sociaal_minimum_%                                               0.500000
# Huishoudens_tot_120%_van_sociaal_minimum_%                                               1.150000
# Mediaan_vermogen_van_particuliere_huish_x_1_000...                                      -4.900000
# Percentage_jongeren_met_jeugdzorg_%                                                      0.762500
# Personenautos_per_huishouden                                                             0.650000
# Siblings                                                                                -1.355000
# aandeel_mannen                                                                           0.484334
# aandeel_vrouwen                                                                          0.484102
# aandeel_inwoners_0_tot_15_jaar                                                           0.098875
# aandeel_inwoners_15_tot_25_jaar                                                          0.065866
# aandeel_inwoners_25_tot_45_jaar                                                          0.202889
# aandeel_inwoners_45_tot_65_jaar                                                          0.206980
# Gehuwd_aandeel                                                                           0.362641
# Gescheiden_aandeel                                                                       0.007716
# Marokko_aandeel                                                                         -0.014257
# Aruba_aandeel                                                                           -0.007105
# Suriname_aandeel                                                                        -0.006881
# Turkije_aandeel                                                                         -0.018789
# Overig_nietwesters_aandeel                                                              -0.008404
# Opleidingsniveau_laag_aandeel                                                            0.087004
# Opleidingsniveau_hoog_aandeel                                                            0.012634
# Bijstand_aandeel                                                                        -0.014352
# AO_aandeel                                                                               0.019390
# WW_aandeel                                                                              -0.012091
# AOW_aandeel                                                                              0.046573
# Jongeren_met_jeugdzorg_in_natura_aandeel                                                 0.009545
# aandeel_eenpersoonshuishoudens                                                           0.232088
# aandeel_meerpersoonshuishoudens_zonder_kind                                              0.257828
# aandeel_eenouderhuishoudens                                                              0.027001
# aandeel_tweeouderhuishoudens                                                             0.183458
# aandeel_personen_met_uitkering_onder_aowlft                                              0.017050
# aandeel_meergezins_woningen                                                              0.005296
# aandeel_huurwoningen_in_bezit_woningcorporaties                                          0.053757
# aandeel_niet_bewoonde_woningen                                                           0.011942
# Leeftijd_moeder                                                                         16.843750
# Leeftijd_ouder2                                                                         16.885417
#
# Cluster                                             Bovengrens uitschieters (niet gevaccineerden)  \
# gemiddelde_woz_waarde_woning                                                           386.000000
# Nettoarbeidsparticipatie_%                                                              80.000000
# Huishoudens_laagste_landelijke_40%_huishoudensi...                                      47.150000
# Huishoudens_hoogste_landelijke_20%_huishoudensi...                                      38.412500
# Huishoudens_met_een_laag_inkomen_%                                                       7.712500
# Huish_onder_of_rond_sociaal_minimum_%                                                    8.112500
# Huishoudens_tot_110%_van_sociaal_minimum_%                                              12.500000
# Huishoudens_tot_120%_van_sociaal_minimum_%                                              16.750000
# Mediaan_vermogen_van_particuliere_huish_x_1_000...                                     382.300000
# Percentage_jongeren_met_jeugdzorg_%                                                     17.462500
# Personenautos_per_huishouden                                                             1.850000
# Siblings                                                                                 4.925000
# aandeel_mannen                                                                           0.513432
# aandeel_vrouwen                                                                          0.517645
# aandeel_inwoners_0_tot_15_jaar                                                           0.247194
# aandeel_inwoners_15_tot_25_jaar                                                          0.178307
# aandeel_inwoners_25_tot_45_jaar                                                          0.249159
# aandeel_inwoners_45_tot_65_jaar                                                          0.336186
# Gehuwd_aandeel                                                                           0.528569
# Gescheiden_aandeel                                                                       0.116172
# Marokko_aandeel                                                                          0.023761
# Aruba_aandeel                                                                            0.011842
# Suriname_aandeel                                                                         0.011468
# Turkije_aandeel                                                                          0.031315
# Overig_nietwesters_aandeel                                                               0.065756
# Opleidingsniveau_laag_aandeel                                                            0.420650
# Opleidingsniveau_hoog_aandeel                                                            0.263387

# Mediaan_vermogen_van_particuliere_huish_x_1_000...                232.100000
# Percentage_jongeren_met_jeugdzorg_%                                10.337000
# Personenautos_per_huishouden                                        1.300000
# Siblings                                                            1.000000
# aandeel_mannen                                                      0.497086
# aandeel_vrouwen                                                     0.502914
# aandeel_inwoners_0_tot_15_jaar                                      0.155925
# aandeel_inwoners_15_tot_25_jaar                                     0.108061
# aandeel_inwoners_25_tot_45_jaar                                     0.221264
# aandeel_inwoners_45_tot_65_jaar                                     0.284423
# Gehuwd_aandeel                                                      0.439207
# Gescheiden_aandeel                                                  0.067034
# Marokko_aandeel                                                     0.003965
# Aruba_aandeel                                                       0.003578
# Suriname_aandeel                                                    0.003965
# Turkije_aandeel                                                     0.003984
# Overig_nietwesters_aandeel                                          0.029197
# Opleidingsniveau_laag_aandeel                                       0.209877
# Opleidingsniveau_hoog_aandeel                                       0.191401
# Bijstand_aandeel                                                    0.010526
# AO_aandeel                                                          0.034188
# WW_aandeel                                                          0.007143
# AOW_aandeel                                                         0.206294
# Jongeren_met_jeugdzorg_in_natura_aandeel                            0.025045
# aandeel_eenpersoonshuishoudens                                      0.279621
# aandeel_meerpersoonshuishoudens_zonder_kind                         0.339286
# aandeel_eenouderhuishoudens                                         0.061990
# aandeel_tweeouderhuishoudens                                        0.301026
# aandeel_personen_met_uitkering_onder_aowlft                         0.054604
# aandeel_meergezins_woningen                                         0.150000
# aandeel_huurwoningen_in_bezit_woningcorporaties                     0.224029
# aandeel_niet_bewoonde_woningen                                      0.030111
# Leeftijd_moeder                                                    31.416667
# Leeftijd_ouder2                                                    33.500000
#
# Cluster                                             SD (gevaccineerden)
# gemiddelde_woz_waarde_woning                                  57.116428
# Nettoarbeidsparticipatie_%                                     4.718167
# Huishoudens_laagste_landelijke_40%_huishoudensi...             9.609127
# Huishoudens_hoogste_landelijke_20%_huishoudensi...             9.305635
# Huishoudens_met_een_laag_inkomen_%                             1.598692
# Huish_onder_of_rond_sociaal_minimum_%                          2.269558
# Huishoudens_tot_110%_van_sociaal_minimum_%                     3.405949
# Huishoudens_tot_120%_van_sociaal_minimum_%                     4.497382
# Mediaan_vermogen_van_particuliere_huish_x_1_000...           130.446979
# Percentage_jongeren_met_jeugdzorg_%                            2.344457
# Personenautos_per_huishouden                                   0.174041
# Siblings                                                       0.848738
# aandeel_mannen                                                 0.011959
# aandeel_vrouwen                                                0.009736
# aandeel_inwoners_0_tot_15_jaar                                 0.022079
# aandeel_inwoners_15_tot_25_jaar                                0.011698
# aandeel_inwoners_25_tot_45_jaar                                0.021474
# aandeel_inwoners_45_tot_65_jaar                                0.022476
# Gehuwd_aandeel                                                 0.042271
# Gescheiden_aandeel                                             0.020654
# Marokko_aandeel                                                0.028004
# Aruba_aandeel                                                  0.004084
# Suriname_aandeel                                               0.003937
# Turkije_aandeel                                                0.017499
# Overig_nietwesters_aandeel                                     0.023149
# Opleidingsniveau_laag_aandeel                                  0.060932
# Opleidingsniveau_hoog_aandeel                                  0.070715
# Bijstand_aandeel                                               0.011776
# AO_aandeel                                                     0.014882
# WW_aandeel                                                     0.004010
# AOW_aandeel                                                    0.060782
# Jongeren_met_jeugdzorg_in_natura_aandeel                       0.006542
# aandeel_eenpersoonshuishoudens                                 0.048061
# aandeel_meerpersoonshuishoudens_zonder_kind                    0.027165
# aandeel_eenouderhuishoudens                                    0.013640
# aandeel_tweeouderhuishoudens                                   0.048529
# aandeel_personen_met_uitkering_onder_aowlft                    0.015406
# aandeel_meergezins_woningen                                    0.084963
# aandeel_huurwoningen_in_bezit_woningcorporaties                0.093609
# aandeel_niet_bewoonde_woningen                                 0.016475
# Leeftijd_moeder                                                4.204110
# Leeftijd_ouder2                                                5.054838

# %%
# Take only boolean columns
X_zuigelingen_categories = X_zuigelingen_notvaccinated.select_dtypes(include=['boolean', 'category'])
X_zuigelingen_vaccinated = X_zuigelingen_vaccinated.select_dtypes(include=['boolean', 'category'])

# Add 'Zuigelingen_status' to the DataFrame
X_zuigelingen_categories['Cluster'] = y_clusters_zuigelingen

# Dictionary to store combined DataFrames
combined_dfs = {}

# Loop over each categorical column
for col in X_zuigelingen_categories.columns:
    if col != 'Cluster':
        # Group by Zuigelingen_status and the current categorical column
        grouped = X_zuigelingen_categories.groupby(['Cluster', col]).size().unstack().T

        # Calculate percentages
        grouped_pct = grouped.div(grouped.sum(axis=0), axis=1) * 100
        
        # Rename percentage columns to include '(%)'
        grouped_pct.columns = [f"{col} (%)" for col in grouped_pct.columns]

        # Calculate total counts and percentages across all clusters
        total_counts = grouped.sum(axis=1)
        total_pct = total_counts / total_counts.sum() * 100
        
        # Calculate total counts and percentages in X_zuigelingen_vaccinated
        total_counts_vaccinated = X_zuigelingen_vaccinated[col].value_counts()
        total_pct_vaccinated = total_counts_vaccinated / total_counts_vaccinated.sum() * 100
        
        # Add total counts and percentages to the DataFrame
        grouped['Totaal (niet gevaccineerden)'] = total_counts
        grouped_pct['Totaal (niet gevaccineerden) (%)'] = total_pct
        
        # Add total counts and percentages in X_zuigelingen_vaccinated to the DataFrame
        grouped['Totaal (gevaccineerden)'] = total_counts_vaccinated
        grouped_pct['Totaal (gevaccineerden) (%)'] = total_pct_vaccinated
        
        # Concatenate counts and percentages horizontally
        combined = pd.concat([grouped, grouped_pct], axis=1)
        
        # Add a new level to the index to preserve the original variable names
        combined.index = pd.MultiIndex.from_product([[col], combined.index])
        
        # Store the combined DataFrame in the dictionary
        combined_dfs[col] = combined

# Concatenate all combined DataFrames vertically
grouped_categories = pd.concat(combined_dfs.values(), axis=0)
grouped_categories
# Out:
#                                                            0     1     2  \
# percentage_geb_nederland_herkomst_nederland_70.0 False  29.0  74.0  92.0
#                                                  True   20.0   NaN   3.0
# percentage_geb_nederland_herkomst_nederland_80.0 False  20.0  74.0  85.0
#                                                  True   29.0   NaN  10.0
# percentage_geb_nederland_herkomst_nederland_90.0 False  49.0   NaN  13.0
# ...                                                      ...   ...   ...
# Geslacht=mannelijk                               True   29.0  38.0  54.0
# Gevaccineerd_ouder1                              False  48.0  72.0  88.0
#                                                  True    1.0   2.0   7.0
# Gevaccineerd_ouder2                              False  43.0  72.0  86.0
#                                                  True    6.0   2.0   9.0
#
#                                                         Totaal (niet gevaccineerden)  \
# percentage_geb_nederland_herkomst_nederland_70.0 False                         195.0
#                                                  True                           23.0
# percentage_geb_nederland_herkomst_nederland_80.0 False                         179.0
#                                                  True                           39.0
# percentage_geb_nederland_herkomst_nederland_90.0 False                          62.0
# ...                                                                              ...
# Geslacht=mannelijk                               True                          121.0
# Gevaccineerd_ouder1                              False                         208.0
#                                                  True                           10.0
# Gevaccineerd_ouder2                              False                         201.0
#                                                  True                           17.0
#
#                                                         Totaal (gevaccineerden)  \
# percentage_geb_nederland_herkomst_nederland_70.0 False                     4421
#                                                  True                       478
# percentage_geb_nederland_herkomst_nederland_80.0 False                     3077
#                                                  True                      1822
# percentage_geb_nederland_herkomst_nederland_90.0 False                     2307
# ...                                                                         ...
# Geslacht=mannelijk                               True                      2490
# Gevaccineerd_ouder1                              False                     1351
#                                                  True                      3548
# Gevaccineerd_ouder2                              False                     1343
#                                                  True                      3556
#
#                                                              0 (%)  \
# percentage_geb_nederland_herkomst_nederland_70.0 False   59.183673
#                                                  True    40.816327
# percentage_geb_nederland_herkomst_nederland_80.0 False   40.816327
#                                                  True    59.183673
# percentage_geb_nederland_herkomst_nederland_90.0 False  100.000000
# ...                                                            ...
# Geslacht=mannelijk                               True    59.183673
# Gevaccineerd_ouder1                              False   97.959184
#                                                  True     2.040816
# Gevaccineerd_ouder2                              False   87.755102
#                                                  True    12.244898
#
#                                                              1 (%)      2 (%)  \
# percentage_geb_nederland_herkomst_nederland_70.0 False  100.000000  96.842105
#                                                  True          NaN   3.157895
# percentage_geb_nederland_herkomst_nederland_80.0 False  100.000000  89.473684
#                                                  True          NaN  10.526316
# percentage_geb_nederland_herkomst_nederland_90.0 False         NaN  13.684211
# ...                                                            ...        ...
# Geslacht=mannelijk                               True    51.351351  56.842105
# Gevaccineerd_ouder1                              False   97.297297  92.631579
#                                                  True     2.702703   7.368421
# Gevaccineerd_ouder2                              False   97.297297  90.526316
#                                                  True     2.702703   9.473684
#
#                                                         Totaal (niet gevaccineerden) (%)  \
# percentage_geb_nederland_herkomst_nederland_70.0 False                         89.449541
#                                                  True                          10.550459
# percentage_geb_nederland_herkomst_nederland_80.0 False                         82.110092
#                                                  True                          17.889908
# percentage_geb_nederland_herkomst_nederland_90.0 False                         28.440367
# ...                                                                                  ...
# Geslacht=mannelijk                               True                          55.504587
# Gevaccineerd_ouder1                              False                         95.412844
#                                                  True                           4.587156
# Gevaccineerd_ouder2                              False                         92.201835
#                                                  True                           7.798165
#
#                                                         Totaal (gevaccineerden) (%)
# percentage_geb_nederland_herkomst_nederland_70.0 False                    90.242907
#                                                  True                      9.757093
# percentage_geb_nederland_herkomst_nederland_80.0 False                    62.808736
#                                                  True                     37.191264
# percentage_geb_nederland_herkomst_nederland_90.0 False                    47.091243
# ...                                                                             ...
# Geslacht=mannelijk                               True                     50.826699
# Gevaccineerd_ouder1                              False                    27.577057
#                                                  True                     72.422943
# Gevaccineerd_ouder2                              False                    27.413758
#                                                  True                     72.586242
#
# [72 rows x 10 columns]

# %% [markdown]
# #### 4.4 Structure and save results

# %%
# Print general info
print(f'In de data zijn {n_clusters} clusters gevonden. Het cluster waartoe een individu behoort kan op basis van zijn of haar kenmerken voorspeld worden met een \'accuracy\' van {accuracy:.2f}.')
# Example value for 'today'
today = datetime.now().strftime('%Y-%m-%d')
# Make target folder to place plots
os.makedirs(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters')
# Out:
# In de data zijn 3 clusters gevonden. Het cluster waartoe een individu behoort kan op basis van zijn of haar kenmerken voorspeld worden met een 'accuracy' van 1.00.

# %%
# Split the array into a list of arrays, one for each class
multi_shap_vals = [shap_values[:, :, i] for i in range(shap_values.shape[2])]

# Plot the SHAP values with feature names
shap.summary_plot(multi_shap_vals, X_train.values, plot_type='bar', class_names=le_classes, feature_names=X_train.columns, plot_size=(15, 10), show=False)
plt.title('SHAP Summary Plot')
plt.savefig(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters\\SHAP_summary_plot.jpg', dpi=300, bbox_inches='tight')
plt.close()

# Save grouped_continuous and grouped_categories to a .xlsx file on two separate sheets
with pd.ExcelWriter(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters\\Clusterkenmerken.xlsx') as writer:
    grouped_continuous.to_excel(writer, sheet_name='Kenmerken_continu')
    grouped_categories.to_excel(writer, sheet_name='Kenmerken_categorisch')

# If -1 is in the labels, begin with second color in palette
if -1 in hdb.labels_:
    plt.figure(figsize=(12, 7))
    plt.title(f'HDBSCAN clustering - (min_cluster_size={min_cluster_size}, min_samples={min_samples})')
    hdb.condensed_tree_.plot(select_clusters=True, selection_palette=sns.color_palette()[1:])
    plt.savefig(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters\\HDBSCAN_tree.jpg', dpi=300, bbox_inches='tight')
    plt.close()
else:
    plt.figure(figsize=(12, 7))
    plt.title(f'HDBSCAN clustering - (min_cluster_size={min_cluster_size}, min_samples={min_samples})')
    hdb.condensed_tree_.plot(select_clusters=True, selection_palette=sns.color_palette())
    plt.savefig(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters\\HDBSCAN_tree.jpg', dpi=300, bbox_inches='tight')
    plt.close()

# Print summary plot per cluster
for cluster in range(1, n_clusters+1):

    # Make target folder to place plots
    os.makedirs(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters\\Cluster_{cluster}')
    
    # Calculate shap dim
    if -1 in y_clusters_zuigelingen:
        cluster_dim = cluster
    else:
        cluster_dim = cluster - 1

    # Plot the SHAP summary plot
    shap.summary_plot(shap_values[:, :, cluster_dim], X_train, feature_names=X_train.columns, plot_size=(15, 10), show=False, max_display=15)
    plt.title(f'SHAP cluster {cluster} plot')
    plt.savefig(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters\\Cluster_{cluster}\\SHAP_cluster_plot.jpg', dpi=300, bbox_inches='tight')
    plt.close()

    # Plot neighbourhoods
    cmap = mcolors.LinearSegmentedColormap.from_list('unidirectional', ['lightcoral', 'darkred'])
    gdf.plot(column=cluster-1,
            cmap=cmap,
            legend=True)
    plt.axis('off')
    plt.title(f'Niet-gevaccineerden per buurt - Cluster {cluster} (*100%)')
    plt.savefig(f'../9_Results\\Zuigelingen\\Not_vaccinated\\15D\\{today}_Clusters\\Cluster_{cluster}\\Neighbourhoods.jpg', dpi=300, bbox_inches='tight')
    plt.close()
